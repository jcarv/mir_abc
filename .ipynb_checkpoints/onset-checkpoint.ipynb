# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display

# %%
x, sr = librosa.load('/home/kumpaka/Desktop/Songs/839.wav')
librosa.display.waveplot(x, sr=sr,max_points=20)
